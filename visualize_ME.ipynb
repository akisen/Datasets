# %%
ls /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.*.fits
# Out:
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.alpha_err.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.alpha_mag.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.azimuth.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.azimuth_alpha_err.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.azimuth_err.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.chisq.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.confid_map.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.conv_flag.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.damping.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.dop_width.fits
# /media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.eta_0.fits
# ...

# %%
import sunpy.map
path = "/media/akito/Data/hmi_ME/20100407/hmi.ME_720s_fd10.20100407_070000_TAI.dop_width.fits"
map =sunpy.map.Map(path)
map
# Out:
# WARNING: FITSFixedWarning: CRDER1 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: CRDER2 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: CRDER1 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: CRDER2 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: CRDER1 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: CRDER2 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: CRDER1 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: CRDER2 = 'nan '
# a floating-point value was expected. [astropy.wcs.wcs]
# ...

# %%
import datetime 
test = datetime.datetime(2010,2,28)
test+datetime.timedelta(days=1)
# Out:
# datetime.datetime(2010, 3, 1, 0, 0)
